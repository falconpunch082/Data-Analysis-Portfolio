# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 627

# %%
# Checking cities list
cities
# Out:
# ['vilyuysk',
#  'papao',
#  'taiohae',
#  'grytviken',
#  'columbia falls',
#  'blackmans bay',
#  'xiaoweizhai',
#  'kodiak',
#  'ribeira grande',
#  'wenling',
#  'albany',
#  'namibe',
#  'waitangi',
#  'ushuaia',
#  'dunedin',
#  'madison',
#  'hoemul-li',
#  'hermanus',
#  'badger',
#  'bilibino',
#  'maine soroa',
#  'puerto natales',
#  'nemuro',
#  'remire-montjoly',
#  'weno',
#  'monte argentario',
#  'whitehorse',
#  'hawaiian paradise park',
#  'mangrol',
#  'palermo',
#  'port moresby',
#  'gizo',
#  'puerto san carlos',
#  'dudinka',
#  'port lincoln',
#  'tindouf',
#  'ghat',
#  'nadym',
#  'yellowknife',
#  'alice springs',
#  'bubaque',
#  'toliara',
#  'nishinoomote',
#  'lazaro cardenas',
#  'port-aux-francais',
#  'manokwari',
#  'tura',
#  'gordon',
#  'edinburgh of the seven seas',
#  'saudarkrokur',
#  'barcelos',
#  'saldanha',
#  'yankton',
#  'hadibu',
#  'o rosal',
#  'puerto ayora',
#  'sulmona',
#  'luderitz',
#  'portland',
#  'sretensk',
#  'invercargill',
#  'varkaus',
#  'kawthoung',
#  'leua',
#  'south upi',
#  'utrik',
#  'constantia',
#  'west island',
#  'petropavlovsk-kamchatsky',
#  'margaret river',
#  'newala kisimani',
#  'freetown',
#  'hurricane',
#  'mount pearl',
#  'college',
#  'spanish wells',
#  'port elizabeth',
#  'stanley',
#  'taro',
#  'susuman',
#  'vilyuchinsk',
#  'punta arenas',
#  'tiksi',
#  'saveh',
#  'colonia',
#  'ar rutbah',
#  'katsuura',
#  'lorengau',
#  "st. john's",
#  'salym',
#  'villa gesell',
#  'port mathurin',
#  'camalu',
#  'sola',
#  'igrim',
#  'richards bay',
#  'griffin',
#  'fale old settlement',
#  'bredasdorp',
#  'vyazemskiy',
#  'wailua homesteads',
#  'los andes',
#  'yanchep',
#  'anadyr',
#  'xunchang',
#  'sinop',
#  'antofagasta',
#  'pisco',
#  'adamstown',
#  'yevpatoriya',
#  'vila velha',
#  'bel ombre',
#  'hasaki',
#  'lebu',
#  'daye',
#  'gadzhiyevo',
#  'fuvahmulah',
#  'geraldton',
#  'thompson',
#  'jamestown',
#  'mar del plata',
#  'prineville',
#  'linqiong',
#  'enewetak',
#  'po',
#  "dul'durga",
#  'devils lake',
#  'vorgashor',
#  'malanje',
#  'chibougamau',
#  'newnan',
#  'ust-nera',
#  'kununurra',
#  'laguna',
#  'santo antonio',
#  'cabo san lucas',
#  'turpan',
#  'bayan nur',
#  'banda aceh',
#  'konstantinovka',
#  'camlidere',
#  'sinan',
#  "rossosh'",
#  'nova sintra',
#  'quellon',
#  'choyr',
#  'ranot',
#  'bethel',
#  'koundara',
#  'luanda',
#  'oodweyne',
#  'papatowai',
#  'vadso',
#  'tubarjal',
#  'lucenec',
#  'tralee',
#  'nasir',
#  'thurso',
#  'kuala kedah',
#  'nogliki',
#  'ndelele',
#  "'ohonua",
#  'georgetown',
#  'arno',
#  'puerto deseado',
#  'labrador city',
#  'hithadhoo',
#  'urangan',
#  'klyuchi',
#  'oamaru',
#  'port alfred',
#  'karratha',
#  'bridgewater',
#  'iskateley',
#  'olyokminsk',
#  "n'zeto",
#  'armidale',
#  'saint-louis',
#  'undurkhaan',
#  'arraial do cabo',
#  'nikel',
#  'namtsy',
#  'alotau',
#  'cole harbour',
#  'hamilton',
#  'olonkinbyen',
#  'kamina',
#  'island harbour',
#  'guane',
#  'gisborne',
#  'lianhe',
#  'impfondo',
#  'xilin hot',
#  'bonthe',
#  'rantauprapat',
#  'lihue',
#  'shanga',
#  'iqaluit',
#  'udachny',
#  'tamanrasset',
#  'ilulissat',
#  'kourou',
#  'agat village',
#  'sines',
#  'demre',
#  'haiku-pauwela',
#  'devinuwara',
#  'el hadjira',
#  'lospalos',
#  'ouarzazat',
#  'malpica',
#  'tarawa',
#  'leava',
#  'yuzhno-kurilsk',
#  'crane',
#  'puerto aysen',
#  'longyearbyen',
#  'keflavik',
#  'san patricio',
#  'tazacorte',
#  'san marcos de colon',
#  'strathalbyn',
#  'alesund',
#  'mildura',
#  'mukalla',
#  'kiunga',
#  'riohacha',
#  "hayma'",
#  'mount isa',
#  'itapirapua',
#  'margate',
#  'kadugli',
#  'cangas del narcea',
#  'los frentones',
#  'usinsk',
#  'merizo village',
#  'kaohsiung',
#  'abadiania',
#  'san rafael',
#  'wahpeton',
#  'pelabuhanratu',
#  'illizi',
#  'carutapera',
#  'talnakh',
#  'glace bay',
#  'lata',
#  'goundam',
#  'ancud',
#  'kananya',
#  'erenhot',
#  'midvagur',
#  'piacabucu',
#  'isafjordur',
#  'avarua',
#  'christchurch',
#  'rovaniemi',
#  'santa maria del oro',
#  'cannonvale',
#  'gaspe',
#  'turabah',
#  'bethanie',
#  'castillos',
#  'prince rupert',
#  'hermiston',
#  'tazovsky',
#  'kailua-kona',
#  'lompoc',
#  'sao joao da barra',
#  'fort st. john',
#  'springbok',
#  'san cristobal',
#  'ugoofaaru',
#  'salinopolis',
#  'genhe',
#  'ronneby',
#  'uzgen',
#  'bom jardim',
#  'celestun',
#  "kapa'a",
#  'fannuj',
#  'baharly',
#  'omagh',
#  'new norfolk',
#  "heniches'k",
#  'cabedelo',
#  'burao',
#  'sydney mines',
#  'wynyard',
#  'goondiwindi',
#  'ola',
#  'al mayadin',
#  'uturoa',
#  'kenai',
#  'broome',
#  'springhill',
#  'maumere',
#  'wegorzewo',
#  'bloemfontein',
#  'camacupa',
#  'saint-philippe',
#  'yorkton',
#  'talakan',
#  'chiili',
#  "sol'-iletsk",
#  'taoudenni',
#  'qaqortoq',
#  'nizhnyaya omka',
#  'chonchi',
#  'la mira',
#  'argo',
#  'langsa',
#  'christiana',
#  'hilton head island',
#  'masterton',
#  'gerena',
#  'howrah',
#  'igarka',
#  'jabat',
#  'palikir - national government center',
#  'passos',
#  'trujillo',
#  'arivonimamo',
#  'inekar',
#  'bhattiprolu',
#  'minas de marcona',
#  'ulladulla',
#  'aasiaat',
#  'qarauyl',
#  'alofi',
#  'swift current',
#  'neiafu',
#  'tamandare',
#  'barcelona',
#  'nova vicosa',
#  'sabang',
#  'umluj',
#  'khandyga',
#  'camana',
#  'axim',
#  'xining',
#  'santa maria',
#  'san antonio de pale',
#  'chu',
#  'baishishan',
#  'afaahiti',
#  'rabo de peixe',
#  'saratamata',
#  'choibalsan',
#  'thabazimbi',
#  'rio gallegos',
#  'livingston',
#  'york beach',
#  'strezhevoy',
#  'atafu village',
#  'chaihe',
#  'lovington',
#  'ibotirama',
#  'chapaev',
#  'tolanaro',
#  'sitka',
#  'tateyama',
#  'jalai nur',
#  'chela',
#  'san juan de miraflores',
#  'hotan',
#  'suva',
#  'coquimbo',
#  'newman',
#  'basco',
#  'walvis bay',
#  'santa rosa misiones',
#  'limassol',
#  'kruisfontein',
#  'sanming',
#  "sysert'",
#  'aykhal',
#  'nongstoin',
#  'mazagao',
#  'hereford',
#  'plettenberg bay',
#  'pangoa',
#  'saint-pierre',
#  'arecibo',
#  'paracuru',
#  'qasr-e qand',
#  'princeville',
#  'luba',
#  'zigong',
#  'puno',
#  'kashgar',
#  'pemangkat',
#  'filipstad',
#  'lerwick',
#  'nagqu',
#  'libreville',
#  'burang',
#  'tachilek',
#  'jaipur',
#  'faya-largeau',
#  'fergus falls',
#  'kubrat',
#  'seryshevo',
#  'codrington',
#  'manturovo',
#  'manghit',
#  'gueltat zemmour',
#  'san buenaventura',
#  'selfoss',
#  'oualidia',
#  'bamboo flat',
#  'carnarvon',
#  'raurkela',
#  'korla',
#  'rundu',
#  "mil'kovo",
#  'beboto',
#  'itoman',
#  'sorong',
#  'san marcos',
#  'rochelle',
#  'mont-dore',
#  'seredyna-buda',
#  'niafunke',
#  'barkot',
#  'gokwe',
#  'ta`u',
#  'hammerfest',
#  'fisterra',
#  'gariaband',
#  'kiomboi',
#  'san juan',
#  'sur',
#  'cill airne',
#  'naracoorte',
#  'rikaze',
#  'virginia beach',
#  'arteche',
#  'tranovaho',
#  'inza',
#  'lind',
#  'tual',
#  'olofstrom',
#  'dalbandin',
#  'mana',
#  'mangai',
#  'timbiqui',
#  'lakatoro',
#  'saipan',
#  'alibag',
#  'magadan',
#  "diok'nisi",
#  'zhangye',
#  'altay',
#  'old town',
#  'vila franca do campo',
#  'kill devil hills',
#  'powell',
#  'narman',
#  'prado',
#  'sungailiat',
#  'necochea',
#  'opuwo',
#  'lodja',
#  'kirakira',
#  'usogorsk',
#  'gamay',
#  'farmville',
#  'flying fish cove',
#  "nar'yan-mar",
#  'harper',
#  'pithiviers',
#  'egilsstadir',
#  'kismayo',
#  'sterling',
#  'horta',
#  'huarmey',
#  'queenstown',
#  'rio grande',
#  'al jawf',
#  'watsa',
#  'yigo village',
#  'touros',
#  'polyarnyy',
#  'nago',
#  'cidreira',
#  'okhotsk',
#  'inari',
#  'were ilu',
#  'porto novo',
#  'yanam',
#  'tobelo',
#  "prokop'yevsk",
#  'east london',
#  'kendari',
#  'san pedro pochutla',
#  'elliot lake',
#  'sitangkai',
#  'mejit',
#  'pineville',
#  'matthew town',
#  'thisted',
#  'cedeira',
#  'laguna paiva',
#  'safotu',
#  'inhambane',
#  'dikwa',
#  'dwarka',
#  'kone',
#  'del rio',
#  'palmer',
#  'vorkuta',
#  'sonsorol village',
#  'east end',
#  'brisas de zicatela',
#  'wuhai',
#  'al-`ula',
#  'dryden',
#  'kievka',
#  'luena',
#  'sittwe',
#  'vondrozo',
#  'kotli loharan',
#  'bafang',
#  'cruzeiro do sul',
#  'shimoda',
#  'togur',
#  'jinchang',
#  'progreso',
#  'the pas',
#  'alta gracia',
#  'kuje',
#  'bandon',
#  'abomey',
#  'yima',
#  'yeed',
#  'mitu',
#  'mount gambier',
#  'dalby',
#  'east ballina',
#  'lycksele',
#  'aioun',
#  'lisala',
#  'buka',
#  'trinidad',
#  'federal',
#  'greymouth',
#  'jeddah',
#  'nikolayevsk-on-amure',
#  'sjobo',
#  'yondo',
#  'tucurui',
#  'broken hill',
#  'parang',
#  'ahtari',
#  'ndele',
#  'al mijlad',
#  "nuku'alofa",
#  'malakal',
#  'vikulovo',
#  'conduaga',
#  "ust'-ilimsk",
#  'antonio enes',
#  'westport',
#  'nyurba',
#  'chinde',
#  'pinotepa nacional',
#  'happy valley-goose bay',
#  'nanzhang chengguanzhen',
#  "roslavl'",
#  'kidal',
#  'tofol',
#  'saint-joseph',
#  'askoy',
#  'berryville',
#  'tamboril',
#  'san luis',
#  'smithers',
#  'constitucion',
#  'najran',
#  'la passe',
#  'aripuana',
#  'heunghae',
#  'kuusamo',
#  'myitkyina',
#  'dickinson',
#  'gagarawa',
#  'kargasok',
#  'gondar',
#  'ormeau',
#  'byron bay',
#  'lashio',
#  'ardestan',
#  'serchhip',
#  'murashi',
#  'caglayancerit',
#  'mbanza-ngungu',
#  'raton',
#  'ulan bator',
#  'ilha de mocambique',
#  'aras-asan',
#  'borogontsy',
#  'naze',
#  'hilo',
#  'badiyah',
#  'nampa',
#  'acapulco de juarez',
#  'luwuk',
#  'krasnoarmeyskaya',
#  'shakawe',
#  'villa union',
#  'hecun',
#  'thinadhoo',
#  'haparanda',
#  'paradip garh',
#  'kamaishi',
#  'azemmour',
#  'umatac village',
#  'az zulfi',
#  'point pedro',
#  'mersing',
#  'hami',
#  'ormara',
#  'tukrah',
#  "ha'il",
#  'sandnessjoen',
#  'hattiesburg',
#  'beteza']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "q=" + city + "&appid=" + weather_api_key + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vilyuysk
# Processing Record 2 of Set 1 | papao
# Processing Record 3 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | columbia falls
# Processing Record 6 of Set 1 | blackmans bay
# Processing Record 7 of Set 1 | xiaoweizhai
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | wenling
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | namibe
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | dunedin
# Processing Record 16 of Set 1 | madison
# Processing Record 17 of Set 1 | hoemul-li
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | badger
# Processing Record 20 of Set 1 | bilibino
# Processing Record 21 of Set 1 | maine soroa
# Processing Record 22 of Set 1 | puerto natales
# Processing Record 23 of Set 1 | nemuro
# Processing Record 24 of Set 1 | remire-montjoly
# Processing Record 25 of Set 1 | weno
# Processing Record 26 of Set 1 | monte argentario
# Processing Record 27 of Set 1 | whitehorse
# Processing Record 28 of Set 1 | hawaiian paradise park
# Processing Record 29 of Set 1 | mangrol
# Processing Record 30 of Set 1 | palermo
# Processing Record 31 of Set 1 | port moresby
# Processing Record 32 of Set 1 | gizo
# Processing Record 33 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 34 of Set 1 | dudinka
# Processing Record 35 of Set 1 | port lincoln
# Processing Record 36 of Set 1 | tindouf
# Processing Record 37 of Set 1 | ghat
# Processing Record 38 of Set 1 | nadym
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | alice springs
# Processing Record 41 of Set 1 | bubaque
# Processing Record 42 of Set 1 | toliara
# Processing Record 43 of Set 1 | nishinoomote
# Processing Record 44 of Set 1 | lazaro cardenas
# Processing Record 45 of Set 1 | port-aux-francais
# Processing Record 46 of Set 1 | manokwari
# Processing Record 47 of Set 1 | tura
# Processing Record 48 of Set 1 | gordon
# Processing Record 49 of Set 1 | edinburgh of the seven seas
# Processing Record 50 of Set 1 | saudarkrokur
# Processing Record 0 of Set 2 | barcelos
# Processing Record 1 of Set 2 | saldanha
# Processing Record 2 of Set 2 | yankton
# Processing Record 3 of Set 2 | hadibu
# Processing Record 4 of Set 2 | o rosal
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | sulmona
# Processing Record 7 of Set 2 | luderitz
# Processing Record 8 of Set 2 | portland
# Processing Record 9 of Set 2 | sretensk
# Processing Record 10 of Set 2 | invercargill
# Processing Record 11 of Set 2 | varkaus
# Processing Record 12 of Set 2 | kawthoung
# City not found. Skipping...
# Processing Record 13 of Set 2 | leua
# Processing Record 14 of Set 2 | south upi
# Processing Record 15 of Set 2 | utrik
# Processing Record 16 of Set 2 | constantia
# Processing Record 17 of Set 2 | west island
# Processing Record 18 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 19 of Set 2 | margaret river
# Processing Record 20 of Set 2 | newala kisimani
# Processing Record 21 of Set 2 | freetown
# Processing Record 22 of Set 2 | hurricane
# Processing Record 23 of Set 2 | mount pearl
# Processing Record 24 of Set 2 | college
# Processing Record 25 of Set 2 | spanish wells
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | stanley
# Processing Record 28 of Set 2 | taro
# Processing Record 29 of Set 2 | susuman
# Processing Record 30 of Set 2 | vilyuchinsk
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | tiksi
# Processing Record 33 of Set 2 | saveh
# Processing Record 34 of Set 2 | colonia
# Processing Record 35 of Set 2 | ar rutbah
# Processing Record 36 of Set 2 | katsuura
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | st. john's
# Processing Record 39 of Set 2 | salym
# Processing Record 40 of Set 2 | villa gesell
# Processing Record 41 of Set 2 | port mathurin
# Processing Record 42 of Set 2 | camalu
# Processing Record 43 of Set 2 | sola
# Processing Record 44 of Set 2 | igrim
# Processing Record 45 of Set 2 | richards bay
# Processing Record 46 of Set 2 | griffin
# Processing Record 47 of Set 2 | fale old settlement
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | vyazemskiy
# Processing Record 0 of Set 3 | wailua homesteads
# Processing Record 1 of Set 3 | los andes
# Processing Record 2 of Set 3 | yanchep
# Processing Record 3 of Set 3 | anadyr
# Processing Record 4 of Set 3 | xunchang
# Processing Record 5 of Set 3 | sinop
# Processing Record 6 of Set 3 | antofagasta
# Processing Record 7 of Set 3 | pisco
# Processing Record 8 of Set 3 | adamstown
# Processing Record 9 of Set 3 | yevpatoriya
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | bel ombre
# Processing Record 12 of Set 3 | hasaki
# Processing Record 13 of Set 3 | lebu
# Processing Record 14 of Set 3 | daye
# Processing Record 15 of Set 3 | gadzhiyevo
# Processing Record 16 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 17 of Set 3 | geraldton
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | prineville
# Processing Record 22 of Set 3 | linqiong
# Processing Record 23 of Set 3 | enewetak
# Processing Record 24 of Set 3 | po
# City not found. Skipping...
# Processing Record 25 of Set 3 | dul'durga
# Processing Record 26 of Set 3 | devils lake
# Processing Record 27 of Set 3 | vorgashor
# Processing Record 28 of Set 3 | malanje
# Processing Record 29 of Set 3 | chibougamau
# Processing Record 30 of Set 3 | newnan
# Processing Record 31 of Set 3 | ust-nera
# Processing Record 32 of Set 3 | kununurra
# Processing Record 33 of Set 3 | laguna
# Processing Record 34 of Set 3 | santo antonio
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | turpan
# Processing Record 37 of Set 3 | bayan nur
# City not found. Skipping...
# Processing Record 38 of Set 3 | banda aceh
# Processing Record 39 of Set 3 | konstantinovka
# Processing Record 40 of Set 3 | camlidere
# Processing Record 41 of Set 3 | sinan
# Processing Record 42 of Set 3 | rossosh'
# Processing Record 43 of Set 3 | nova sintra
# Processing Record 44 of Set 3 | quellon
# Processing Record 45 of Set 3 | choyr
# Processing Record 46 of Set 3 | ranot
# Processing Record 47 of Set 3 | bethel
# Processing Record 48 of Set 3 | koundara
# Processing Record 49 of Set 3 | luanda
# Processing Record 0 of Set 4 | oodweyne
# Processing Record 1 of Set 4 | papatowai
# Processing Record 2 of Set 4 | vadso
# Processing Record 3 of Set 4 | tubarjal
# Processing Record 4 of Set 4 | lucenec
# Processing Record 5 of Set 4 | tralee
# Processing Record 6 of Set 4 | nasir
# Processing Record 7 of Set 4 | thurso
# Processing Record 8 of Set 4 | kuala kedah
# Processing Record 9 of Set 4 | nogliki
# Processing Record 10 of Set 4 | ndelele
# Processing Record 11 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | arno
# Processing Record 14 of Set 4 | puerto deseado
# Processing Record 15 of Set 4 | labrador city
# Processing Record 16 of Set 4 | hithadhoo
# Processing Record 17 of Set 4 | urangan
# Processing Record 18 of Set 4 | klyuchi
# Processing Record 19 of Set 4 | oamaru
# Processing Record 20 of Set 4 | port alfred
# Processing Record 21 of Set 4 | karratha
# Processing Record 22 of Set 4 | bridgewater
# Processing Record 23 of Set 4 | iskateley
# Processing Record 24 of Set 4 | olyokminsk
# Processing Record 25 of Set 4 | n'zeto
# Processing Record 26 of Set 4 | armidale
# Processing Record 27 of Set 4 | saint-louis
# Processing Record 28 of Set 4 | undurkhaan
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | nikel
# Processing Record 31 of Set 4 | namtsy
# Processing Record 32 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 4 | cole harbour
# Processing Record 34 of Set 4 | hamilton
# Processing Record 35 of Set 4 | olonkinbyen
# Processing Record 36 of Set 4 | kamina
# Processing Record 37 of Set 4 | island harbour
# Processing Record 38 of Set 4 | guane
# Processing Record 39 of Set 4 | gisborne
# Processing Record 40 of Set 4 | lianhe
# Processing Record 41 of Set 4 | impfondo
# Processing Record 42 of Set 4 | xilin hot
# Processing Record 43 of Set 4 | bonthe
# Processing Record 44 of Set 4 | rantauprapat
# Processing Record 45 of Set 4 | lihue
# Processing Record 46 of Set 4 | shanga
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | udachny
# Processing Record 49 of Set 4 | tamanrasset
# Processing Record 0 of Set 5 | ilulissat
# Processing Record 1 of Set 5 | kourou
# Processing Record 2 of Set 5 | agat village
# Processing Record 3 of Set 5 | sines
# Processing Record 4 of Set 5 | demre
# Processing Record 5 of Set 5 | haiku-pauwela
# Processing Record 6 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 7 of Set 5 | el hadjira
# Processing Record 8 of Set 5 | lospalos
# Processing Record 9 of Set 5 | ouarzazat
# Processing Record 10 of Set 5 | malpica
# Processing Record 11 of Set 5 | tarawa
# Processing Record 12 of Set 5 | leava
# Processing Record 13 of Set 5 | yuzhno-kurilsk
# Processing Record 14 of Set 5 | crane
# Processing Record 15 of Set 5 | puerto aysen
# Processing Record 16 of Set 5 | longyearbyen
# Processing Record 17 of Set 5 | keflavik
# Processing Record 18 of Set 5 | san patricio
# Processing Record 19 of Set 5 | tazacorte
# Processing Record 20 of Set 5 | san marcos de colon
# Processing Record 21 of Set 5 | strathalbyn
# Processing Record 22 of Set 5 | alesund
# Processing Record 23 of Set 5 | mildura
# Processing Record 24 of Set 5 | mukalla
# Processing Record 25 of Set 5 | kiunga
# Processing Record 26 of Set 5 | riohacha
# Processing Record 27 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 28 of Set 5 | mount isa
# Processing Record 29 of Set 5 | itapirapua
# Processing Record 30 of Set 5 | margate
# Processing Record 31 of Set 5 | kadugli
# Processing Record 32 of Set 5 | cangas del narcea
# Processing Record 33 of Set 5 | los frentones
# Processing Record 34 of Set 5 | usinsk
# Processing Record 35 of Set 5 | merizo village
# Processing Record 36 of Set 5 | kaohsiung
# Processing Record 37 of Set 5 | abadiania
# Processing Record 38 of Set 5 | san rafael
# Processing Record 39 of Set 5 | wahpeton
# Processing Record 40 of Set 5 | pelabuhanratu
# Processing Record 41 of Set 5 | illizi
# Processing Record 42 of Set 5 | carutapera
# Processing Record 43 of Set 5 | talnakh
# Processing Record 44 of Set 5 | glace bay
# Processing Record 45 of Set 5 | lata
# Processing Record 46 of Set 5 | goundam
# Processing Record 47 of Set 5 | ancud
# Processing Record 48 of Set 5 | kananya
# Processing Record 49 of Set 5 | erenhot
# Processing Record 0 of Set 6 | midvagur
# Processing Record 1 of Set 6 | piacabucu
# Processing Record 2 of Set 6 | isafjordur
# Processing Record 3 of Set 6 | avarua
# Processing Record 4 of Set 6 | christchurch
# Processing Record 5 of Set 6 | rovaniemi
# Processing Record 6 of Set 6 | santa maria del oro
# Processing Record 7 of Set 6 | cannonvale
# Processing Record 8 of Set 6 | gaspe
# Processing Record 9 of Set 6 | turabah
# Processing Record 10 of Set 6 | bethanie
# Processing Record 11 of Set 6 | castillos
# Processing Record 12 of Set 6 | prince rupert
# Processing Record 13 of Set 6 | hermiston
# Processing Record 14 of Set 6 | tazovsky
# Processing Record 15 of Set 6 | kailua-kona
# Processing Record 16 of Set 6 | lompoc
# Processing Record 17 of Set 6 | sao joao da barra
# Processing Record 18 of Set 6 | fort st. john
# Processing Record 19 of Set 6 | springbok
# Processing Record 20 of Set 6 | san cristobal
# Processing Record 21 of Set 6 | ugoofaaru
# Processing Record 22 of Set 6 | salinopolis
# Processing Record 23 of Set 6 | genhe
# Processing Record 24 of Set 6 | ronneby
# Processing Record 25 of Set 6 | uzgen
# Processing Record 26 of Set 6 | bom jardim
# Processing Record 27 of Set 6 | celestun
# Processing Record 28 of Set 6 | kapa'a
# Processing Record 29 of Set 6 | fannuj
# City not found. Skipping...
# Processing Record 30 of Set 6 | baharly
# Processing Record 31 of Set 6 | omagh
# Processing Record 32 of Set 6 | new norfolk
# Processing Record 33 of Set 6 | heniches'k
# Processing Record 34 of Set 6 | cabedelo
# Processing Record 35 of Set 6 | burao
# Processing Record 36 of Set 6 | sydney mines
# Processing Record 37 of Set 6 | wynyard
# Processing Record 38 of Set 6 | goondiwindi
# Processing Record 39 of Set 6 | ola
# Processing Record 40 of Set 6 | al mayadin
# Processing Record 41 of Set 6 | uturoa
# Processing Record 42 of Set 6 | kenai
# Processing Record 43 of Set 6 | broome
# Processing Record 44 of Set 6 | springhill
# Processing Record 45 of Set 6 | maumere
# Processing Record 46 of Set 6 | wegorzewo
# Processing Record 47 of Set 6 | bloemfontein
# Processing Record 48 of Set 6 | camacupa
# Processing Record 49 of Set 6 | saint-philippe
# Processing Record 0 of Set 7 | yorkton
# Processing Record 1 of Set 7 | talakan
# Processing Record 2 of Set 7 | chiili
# City not found. Skipping...
# Processing Record 3 of Set 7 | sol'-iletsk
# Processing Record 4 of Set 7 | taoudenni
# Processing Record 5 of Set 7 | qaqortoq
# Processing Record 6 of Set 7 | nizhnyaya omka
# Processing Record 7 of Set 7 | chonchi
# Processing Record 8 of Set 7 | la mira
# Processing Record 9 of Set 7 | argo
# Processing Record 10 of Set 7 | langsa
# Processing Record 11 of Set 7 | christiana
# Processing Record 12 of Set 7 | hilton head island
# Processing Record 13 of Set 7 | masterton
# Processing Record 14 of Set 7 | gerena
# Processing Record 15 of Set 7 | howrah
# Processing Record 16 of Set 7 | igarka
# Processing Record 17 of Set 7 | jabat
# Processing Record 18 of Set 7 | palikir - national government center
# Processing Record 19 of Set 7 | passos
# Processing Record 20 of Set 7 | trujillo
# Processing Record 21 of Set 7 | arivonimamo
# Processing Record 22 of Set 7 | inekar
# City not found. Skipping...
# Processing Record 23 of Set 7 | bhattiprolu
# Processing Record 24 of Set 7 | minas de marcona
# Processing Record 25 of Set 7 | ulladulla
# Processing Record 26 of Set 7 | aasiaat
# Processing Record 27 of Set 7 | qarauyl
# Processing Record 28 of Set 7 | alofi
# Processing Record 29 of Set 7 | swift current
# Processing Record 30 of Set 7 | neiafu
# Processing Record 31 of Set 7 | tamandare
# Processing Record 32 of Set 7 | barcelona
# Processing Record 33 of Set 7 | nova vicosa
# Processing Record 34 of Set 7 | sabang
# Processing Record 35 of Set 7 | umluj
# Processing Record 36 of Set 7 | khandyga
# Processing Record 37 of Set 7 | camana
# Processing Record 38 of Set 7 | axim
# Processing Record 39 of Set 7 | xining
# Processing Record 40 of Set 7 | santa maria
# Processing Record 41 of Set 7 | san antonio de pale
# Processing Record 42 of Set 7 | chu
# Processing Record 43 of Set 7 | baishishan
# Processing Record 44 of Set 7 | afaahiti
# Processing Record 45 of Set 7 | rabo de peixe
# Processing Record 46 of Set 7 | saratamata
# City not found. Skipping...
# Processing Record 47 of Set 7 | choibalsan
# Processing Record 48 of Set 7 | thabazimbi
# Processing Record 49 of Set 7 | rio gallegos
# Processing Record 0 of Set 8 | livingston
# Processing Record 1 of Set 8 | york beach
# Processing Record 2 of Set 8 | strezhevoy
# Processing Record 3 of Set 8 | atafu village
# Processing Record 4 of Set 8 | chaihe
# Processing Record 5 of Set 8 | lovington
# Processing Record 6 of Set 8 | ibotirama
# Processing Record 7 of Set 8 | chapaev
# Processing Record 8 of Set 8 | tolanaro
# Processing Record 9 of Set 8 | sitka
# Processing Record 10 of Set 8 | tateyama
# Processing Record 11 of Set 8 | jalai nur
# Processing Record 12 of Set 8 | chela
# Processing Record 13 of Set 8 | san juan de miraflores
# Processing Record 14 of Set 8 | hotan
# Processing Record 15 of Set 8 | suva
# Processing Record 16 of Set 8 | coquimbo
# Processing Record 17 of Set 8 | newman
# Processing Record 18 of Set 8 | basco
# Processing Record 19 of Set 8 | walvis bay
# Processing Record 20 of Set 8 | santa rosa misiones
# Processing Record 21 of Set 8 | limassol
# Processing Record 22 of Set 8 | kruisfontein
# Processing Record 23 of Set 8 | sanming
# Processing Record 24 of Set 8 | sysert'
# Processing Record 25 of Set 8 | aykhal
# Processing Record 26 of Set 8 | nongstoin
# Processing Record 27 of Set 8 | mazagao
# Processing Record 28 of Set 8 | hereford
# Processing Record 29 of Set 8 | plettenberg bay
# Processing Record 30 of Set 8 | pangoa
# Processing Record 31 of Set 8 | saint-pierre
# Processing Record 32 of Set 8 | arecibo
# Processing Record 33 of Set 8 | paracuru
# Processing Record 34 of Set 8 | qasr-e qand
# City not found. Skipping...
# Processing Record 35 of Set 8 | princeville
# Processing Record 36 of Set 8 | luba
# Processing Record 37 of Set 8 | zigong
# Processing Record 38 of Set 8 | puno
# Processing Record 39 of Set 8 | kashgar
# Processing Record 40 of Set 8 | pemangkat
# Processing Record 41 of Set 8 | filipstad
# Processing Record 42 of Set 8 | lerwick
# Processing Record 43 of Set 8 | nagqu
# Processing Record 44 of Set 8 | libreville
# Processing Record 45 of Set 8 | burang
# Processing Record 46 of Set 8 | tachilek
# City not found. Skipping...
# Processing Record 47 of Set 8 | jaipur
# Processing Record 48 of Set 8 | faya-largeau
# Processing Record 49 of Set 8 | fergus falls
# Processing Record 0 of Set 9 | kubrat
# Processing Record 1 of Set 9 | seryshevo
# Processing Record 2 of Set 9 | codrington
# Processing Record 3 of Set 9 | manturovo
# Processing Record 4 of Set 9 | manghit
# Processing Record 5 of Set 9 | gueltat zemmour
# City not found. Skipping...
# Processing Record 6 of Set 9 | san buenaventura
# Processing Record 7 of Set 9 | selfoss
# Processing Record 8 of Set 9 | oualidia
# City not found. Skipping...
# Processing Record 9 of Set 9 | bamboo flat
# Processing Record 10 of Set 9 | carnarvon
# Processing Record 11 of Set 9 | raurkela
# City not found. Skipping...
# Processing Record 12 of Set 9 | korla
# Processing Record 13 of Set 9 | rundu
# Processing Record 14 of Set 9 | mil'kovo
# Processing Record 15 of Set 9 | beboto
# Processing Record 16 of Set 9 | itoman
# Processing Record 17 of Set 9 | sorong
# Processing Record 18 of Set 9 | san marcos
# Processing Record 19 of Set 9 | rochelle
# Processing Record 20 of Set 9 | mont-dore
# Processing Record 21 of Set 9 | seredyna-buda
# Processing Record 22 of Set 9 | niafunke
# Processing Record 23 of Set 9 | barkot
# Processing Record 24 of Set 9 | gokwe
# Processing Record 25 of Set 9 | ta`u
# Processing Record 26 of Set 9 | hammerfest
# Processing Record 27 of Set 9 | fisterra
# Processing Record 28 of Set 9 | gariaband
# Processing Record 29 of Set 9 | kiomboi
# Processing Record 30 of Set 9 | san juan
# Processing Record 31 of Set 9 | sur
# Processing Record 32 of Set 9 | cill airne
# Processing Record 33 of Set 9 | naracoorte
# Processing Record 34 of Set 9 | rikaze
# Processing Record 35 of Set 9 | virginia beach
# Processing Record 36 of Set 9 | arteche
# Processing Record 37 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 38 of Set 9 | inza
# Processing Record 39 of Set 9 | lind
# Processing Record 40 of Set 9 | tual
# Processing Record 41 of Set 9 | olofstrom
# City not found. Skipping...
# Processing Record 42 of Set 9 | dalbandin
# Processing Record 43 of Set 9 | mana
# Processing Record 44 of Set 9 | mangai
# Processing Record 45 of Set 9 | timbiqui
# Processing Record 46 of Set 9 | lakatoro
# Processing Record 47 of Set 9 | saipan
# Processing Record 48 of Set 9 | alibag
# Processing Record 49 of Set 9 | magadan
# Processing Record 0 of Set 10 | diok'nisi
# Processing Record 1 of Set 10 | zhangye
# Processing Record 2 of Set 10 | altay
# Processing Record 3 of Set 10 | old town
# Processing Record 4 of Set 10 | vila franca do campo
# Processing Record 5 of Set 10 | kill devil hills
# Processing Record 6 of Set 10 | powell
# Processing Record 7 of Set 10 | narman
# Processing Record 8 of Set 10 | prado
# Processing Record 9 of Set 10 | sungailiat
# Processing Record 10 of Set 10 | necochea
# Processing Record 11 of Set 10 | opuwo
# Processing Record 12 of Set 10 | lodja
# Processing Record 13 of Set 10 | kirakira
# Processing Record 14 of Set 10 | usogorsk
# Processing Record 15 of Set 10 | gamay
# Processing Record 16 of Set 10 | farmville
# Processing Record 17 of Set 10 | flying fish cove
# Processing Record 18 of Set 10 | nar'yan-mar
# Processing Record 19 of Set 10 | harper
# Processing Record 20 of Set 10 | pithiviers
# Processing Record 21 of Set 10 | egilsstadir
# Processing Record 22 of Set 10 | kismayo
# Processing Record 23 of Set 10 | sterling
# Processing Record 24 of Set 10 | horta
# Processing Record 25 of Set 10 | huarmey
# Processing Record 26 of Set 10 | queenstown
# Processing Record 27 of Set 10 | rio grande
# Processing Record 28 of Set 10 | al jawf
# Processing Record 29 of Set 10 | watsa
# Processing Record 30 of Set 10 | yigo village
# Processing Record 31 of Set 10 | touros
# Processing Record 32 of Set 10 | polyarnyy
# Processing Record 33 of Set 10 | nago
# Processing Record 34 of Set 10 | cidreira
# Processing Record 35 of Set 10 | okhotsk
# Processing Record 36 of Set 10 | inari
# Processing Record 37 of Set 10 | were ilu
# Processing Record 38 of Set 10 | porto novo
# Processing Record 39 of Set 10 | yanam
# Processing Record 40 of Set 10 | tobelo
# Processing Record 41 of Set 10 | prokop'yevsk
# Processing Record 42 of Set 10 | east london
# Processing Record 43 of Set 10 | kendari
# Processing Record 44 of Set 10 | san pedro pochutla
# Processing Record 45 of Set 10 | elliot lake
# Processing Record 46 of Set 10 | sitangkai
# Processing Record 47 of Set 10 | mejit
# Processing Record 48 of Set 10 | pineville
# Processing Record 49 of Set 10 | matthew town
# Processing Record 0 of Set 11 | thisted
# Processing Record 1 of Set 11 | cedeira
# Processing Record 2 of Set 11 | laguna paiva
# Processing Record 3 of Set 11 | safotu
# Processing Record 4 of Set 11 | inhambane
# Processing Record 5 of Set 11 | dikwa
# Processing Record 6 of Set 11 | dwarka
# Processing Record 7 of Set 11 | kone
# Processing Record 8 of Set 11 | del rio
# Processing Record 9 of Set 11 | palmer
# Processing Record 10 of Set 11 | vorkuta
# Processing Record 11 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 12 of Set 11 | east end
# Processing Record 13 of Set 11 | brisas de zicatela
# Processing Record 14 of Set 11 | wuhai
# Processing Record 15 of Set 11 | al-`ula
# City not found. Skipping...
# Processing Record 16 of Set 11 | dryden
# Processing Record 17 of Set 11 | kievka
# Processing Record 18 of Set 11 | luena
# Processing Record 19 of Set 11 | sittwe
# Processing Record 20 of Set 11 | vondrozo
# Processing Record 21 of Set 11 | kotli loharan
# Processing Record 22 of Set 11 | bafang
# Processing Record 23 of Set 11 | cruzeiro do sul
# Processing Record 24 of Set 11 | shimoda
# Processing Record 25 of Set 11 | togur
# Processing Record 26 of Set 11 | jinchang
# Processing Record 27 of Set 11 | progreso
# Processing Record 28 of Set 11 | the pas
# Processing Record 29 of Set 11 | alta gracia
# Processing Record 30 of Set 11 | kuje
# Processing Record 31 of Set 11 | bandon
# Processing Record 32 of Set 11 | abomey
# Processing Record 33 of Set 11 | yima
# Processing Record 34 of Set 11 | yeed
# Processing Record 35 of Set 11 | mitu
# Processing Record 36 of Set 11 | mount gambier
# Processing Record 37 of Set 11 | dalby
# Processing Record 38 of Set 11 | east ballina
# Processing Record 39 of Set 11 | lycksele
# Processing Record 40 of Set 11 | aioun
# Processing Record 41 of Set 11 | lisala
# Processing Record 42 of Set 11 | buka
# Processing Record 43 of Set 11 | trinidad
# Processing Record 44 of Set 11 | federal
# Processing Record 45 of Set 11 | greymouth
# Processing Record 46 of Set 11 | jeddah
# Processing Record 47 of Set 11 | nikolayevsk-on-amure
# Processing Record 48 of Set 11 | sjobo
# City not found. Skipping...
# Processing Record 49 of Set 11 | yondo
# Processing Record 0 of Set 12 | tucurui
# Processing Record 1 of Set 12 | broken hill
# Processing Record 2 of Set 12 | parang
# Processing Record 3 of Set 12 | ahtari
# Processing Record 4 of Set 12 | ndele
# Processing Record 5 of Set 12 | al mijlad
# Processing Record 6 of Set 12 | nuku'alofa
# Processing Record 7 of Set 12 | malakal
# Processing Record 8 of Set 12 | vikulovo
# Processing Record 9 of Set 12 | conduaga
# Processing Record 10 of Set 12 | ust'-ilimsk
# Processing Record 11 of Set 12 | antonio enes
# Processing Record 12 of Set 12 | westport
# Processing Record 13 of Set 12 | nyurba
# Processing Record 14 of Set 12 | chinde
# Processing Record 15 of Set 12 | pinotepa nacional
# Processing Record 16 of Set 12 | happy valley-goose bay
# Processing Record 17 of Set 12 | nanzhang chengguanzhen
# Processing Record 18 of Set 12 | roslavl'
# Processing Record 19 of Set 12 | kidal
# Processing Record 20 of Set 12 | tofol
# Processing Record 21 of Set 12 | saint-joseph
# Processing Record 22 of Set 12 | askoy
# Processing Record 23 of Set 12 | berryville
# Processing Record 24 of Set 12 | tamboril
# Processing Record 25 of Set 12 | san luis
# Processing Record 26 of Set 12 | smithers
# Processing Record 27 of Set 12 | constitucion
# Processing Record 28 of Set 12 | najran
# Processing Record 29 of Set 12 | la passe
# Processing Record 30 of Set 12 | aripuana
# Processing Record 31 of Set 12 | heunghae
# Processing Record 32 of Set 12 | kuusamo
# Processing Record 33 of Set 12 | myitkyina
# Processing Record 34 of Set 12 | dickinson
# Processing Record 35 of Set 12 | gagarawa
# Processing Record 36 of Set 12 | kargasok
# Processing Record 37 of Set 12 | gondar
# Processing Record 38 of Set 12 | ormeau
# Processing Record 39 of Set 12 | byron bay
# Processing Record 40 of Set 12 | lashio
# Processing Record 41 of Set 12 | ardestan
# Processing Record 42 of Set 12 | serchhip
# Processing Record 43 of Set 12 | murashi
# Processing Record 44 of Set 12 | caglayancerit
# Processing Record 45 of Set 12 | mbanza-ngungu
# Processing Record 46 of Set 12 | raton
# Processing Record 47 of Set 12 | ulan bator
# Processing Record 48 of Set 12 | ilha de mocambique
# Processing Record 49 of Set 12 | aras-asan
# Processing Record 0 of Set 13 | borogontsy
# Processing Record 1 of Set 13 | naze
# Processing Record 2 of Set 13 | hilo
# Processing Record 3 of Set 13 | badiyah
# Processing Record 4 of Set 13 | nampa
# Processing Record 5 of Set 13 | acapulco de juarez
# Processing Record 6 of Set 13 | luwuk
# Processing Record 7 of Set 13 | krasnoarmeyskaya
# Processing Record 8 of Set 13 | shakawe
# Processing Record 9 of Set 13 | villa union
# Processing Record 10 of Set 13 | hecun
# Processing Record 11 of Set 13 | thinadhoo
# Processing Record 12 of Set 13 | haparanda
# Processing Record 13 of Set 13 | paradip garh
# Processing Record 14 of Set 13 | kamaishi
# Processing Record 15 of Set 13 | azemmour
# Processing Record 16 of Set 13 | umatac village
# City not found. Skipping...
# Processing Record 17 of Set 13 | az zulfi
# Processing Record 18 of Set 13 | point pedro
# Processing Record 19 of Set 13 | mersing
# Processing Record 20 of Set 13 | hami
# Processing Record 21 of Set 13 | ormara
# Processing Record 22 of Set 13 | tukrah
# Processing Record 23 of Set 13 | ha'il
# Processing Record 24 of Set 13 | sandnessjoen
# Processing Record 25 of Set 13 | hattiesburg
# Processing Record 26 of Set 13 | beteza
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          601
# Lat           601
# Lng           601
# Max Temp      601
# Humidity      601
# Cloudiness    601
# Wind Speed    601
# Country       601
# Date          601
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        vilyuysk  63.7553  121.6247     -3.89        90          41
# 1           papao -17.7500 -149.5500     28.82        80           0
# 2       grytviken -54.2811  -36.5092      4.02        98          98
# 3  columbia falls  48.3725 -114.1815     18.41        56          95
# 4   blackmans bay -43.0167  147.3167      8.62        70          44
#
#    Wind Speed Country        Date
# 0        2.68      RU  1696546751
# 1       12.51      PF  1696546751
# 2        1.50      GS  1696546699
# 3        0.47      US  1696546753
# 4        4.73      AU  1696546753

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              vilyuysk  63.7553  121.6247     -3.89        90          41
# 1                 papao -17.7500 -149.5500     28.82        80           0
# 2             grytviken -54.2811  -36.5092      4.02        98          98
# 3        columbia falls  48.3725 -114.1815     18.41        56          95
# 4         blackmans bay -43.0167  147.3167      8.62        70          44
#
#          Wind Speed Country        Date
# City_ID
# 0              2.68      RU  1696546751
# 1             12.51      PF  1696546751
# 2              1.50      GS  1696546699
# 3              0.47      US  1696546753
# 4              4.73      AU  1696546753

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter", x="Lat", y="Max Temp")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2023-10-06)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (degrees Celcius)")

# Save the figure
plt.savefig("output/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter", x="Lat", y="Humidity")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (2023-10-06)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter", x="Lat", y="Cloudiness")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2023-10-06)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter", x="Lat", y="Wind Speed")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2023-10-06)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
